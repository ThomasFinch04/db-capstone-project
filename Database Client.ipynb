# %%
import mysql.connector as connector

# %%
Password='PleaseWork89'
Username='admin1'

# %%
try:
    connection = connector.connect(user = Username, password = Password, database='littlelemondb')
    print("Connection established")

except connector.Error as err:
    print("Error: {}".format(err))
# Out:
# Connection established

# %%
cursor = connection.cursor()

# %%
show_tables_query = "SHOW tables" 
cursor.execute(show_tables_query)

# %%
results=cursor.fetchall()
print(results)
# Out:
# [('bookings',), ('customers',), ('delivery',), ('menuitems',), ('menus',), ('orders',), ('ordersview',), ('staff',)]

# %%
query = """
select c.FullName, c.email, c.ContactNumber, o.TotalCost 
from Customers as c inner join Orders as o on c.CustomerID = o.CustomerID
where TotalCost>60
"""
cursor.execute(query)
result=cursor.fetchall()
print(cursor.column_names)
for row in result:
    print( row[0],'|',row[1],'|',row[2], '|', float(row[3]))
# Out:
# ('FullName', 'email', 'ContactNumber', 'TotalCost')
# Alice Turner | alice.turner@email.com | 447911123456 | 145.5
# Ben Whitfield | ben.whitfield@email.com | 447911223344 | 210.75
# Chloe Hastings | chloe.hastings@email.com | 447911334455 | 289.99
# Daniel Ferris | daniel.ferris@email.com | 447911445566 | 136.2
# Harry Voss | harry.voss@email.com | 447911667788 | 168.4
# Isla Pemberton | isla.pemberton@email.com | 447911778899 | 199.99
# Jack Sorensen | jack.sorensen@email.com | 447911889900 | 152.1
